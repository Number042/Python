# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt 
import numpy as np
import itertools  
# import sets
import collections as clt
import os
import sys
import difflib as dl  
import re
import timeit
from Input import DataReader, DataSelection
import Plot as pltdat

# %reload_ext autoreload

# %aimport Input
# %aimport Plot

# %autoreload 1
# %matplotlib inline

# mplt.get_configdir()

# %%
mpl.matplotlib_fname()
# Out:
# '/home/mlueckhof/.local/lib/python3.6/site-packages/matplotlib/mpl-data/matplotlibrc'

# %% [markdown]
# Data Input Level
# =========
# Data input by using methods from class Input

# %%
Storage = DataReader(path = ['/home/mlueckhof/Codes/Projects/FCCee/Default/Data/'])
DFseco_col = Storage.readG4out(read = 'secondaries', datType = 'default', verbose = 2)

# beamTypes, beamSizes = Storage.beamList, Storage.beamSizes
# Out:
# files are in: ['/home/mlueckhof/Codes/Projects/FCCee/Default/Data/']
#  ***********************************************
#  accessing directory: /home/mlueckhof/Codes/Projects/FCCee/Default/Data/ ...
#  subdirectories exist for following optics:
#  ['fcc_ee_t_85_by2_nosol', 'fcc_ee_t_205_nosol']
#  -----------------------------
# list of files: []
# WARNING: DatFrame2 empty!
#  accessing directory: /home/mlueckhof/Codes/Projects/FCCee/Default/Data/fcc_ee_t_85_by2_nosol ...
#     ==> no subdirectories.
#     ==> found data.
# ['fcc_ee_t_85_by2_nosol_gauss1_seco_ntuple.out', 'fcc_ee_t_85_by2_nosol_gauss1_prim_ntuple.out', 'fcc_ee_t_85_by2_nosol_ring10_seco_ntuple.out', 'fcc_ee_t_85_by2_nosol_seco_ntuple.out', 'fcc_ee_t_85_by2_nosol_ring10_prim_ntuple.out', 'fcc_ee_t_85_by2_nosol_flat5_seco_ntuple.out', 'fcc_ee_t_85_by2_nosol_prim_ntuple.out', 'fcc_ee_t_85_by2_nosol_flat5_prim_ntuple.out']
# list of files: ['/home/mlueckhof/Codes/Projects/FCCee/Default/Data/fcc_ee_t_85_by2_nosol/fcc_ee_t_85_by2_nosol_gauss1_seco_ntuple.out', '/home/mlueckhof/Codes/Projects/FCCee/Default/Data/fcc_ee_t_85_by2_nosol/fcc_ee_t_85_by2_nosol_ring10_seco_ntuple.out', '/home/mlueckhof/Codes/Projects/FCCee/Default/Data/fcc_ee_t_85_by2_nosol/fcc_ee_t_85_by2_nosol_seco_ntuple.out', '/home/mlueckhof/Codes/Projects/FCCee/Default/Data/fcc_ee_t_85_by2_nosol/fcc_ee_t_85_by2_nosol_flat5_seco_ntuple.out']
#     * beam found:  gauss1
#     * no aperture specified
#    --> appending file: /home/mlueckhof/Codes/Projects/FCCee/Default/Data/fcc_ee_t_85_by2_nosol/fcc_ee_t_85_by2_nosol_gauss1_seco_ntuple.out ...
#     * beam found:  ring10
#     * no aperture specified
#    --> appending file: /home/mlueckhof/Codes/Projects/FCCee/Default/Data/fcc_ee_t_85_by2_nosol/fcc_ee_t_85_by2_nosol_ring10_seco_ntuple.out ...
#     * beam shape: none, set to pencil
#     * no aperture specified
#    --> appending file: /home/mlueckhof/Codes/Projects/FCCee/Default/Data/fcc_ee_t_85_by2_nosol/fcc_ee_t_85_by2_nosol_seco_ntuple.out ...
#     * beam found:  flat5
#     * no aperture specified
#    --> appending file: /home/mlueckhof/Codes/Projects/FCCee/Default/Data/fcc_ee_t_85_by2_nosol/fcc_ee_t_85_by2_nosol_flat5_seco_ntuple.out ...
# DatFrame2 appended
#  accessing directory: /home/mlueckhof/Codes/Projects/FCCee/Default/Data/fcc_ee_t_205_nosol ...
#     ==> no subdirectories.
#     ==> found data.
# ['fcc_ee_t_205_nosol_gauss1_seco_ntuple.out', 'fcc_ee_t_205_nosol_gauss1_prim_ntuple.out']
# list of files: ['/home/mlueckhof/Codes/Projects/FCCee/Default/Data/fcc_ee_t_205_nosol/fcc_ee_t_205_nosol_gauss1_seco_ntuple.out']
#     * beam found:  gauss1
#     * no aperture specified
#    --> appending file: /home/mlueckhof/Codes/Projects/FCCee/Default/Data/fcc_ee_t_205_nosol/fcc_ee_t_205_nosol_gauss1_seco_ntuple.out ...
# DatFrame2 appended

# %% [markdown]
# FCC-ee Parameters
# ---------------------

# %%
file = '/home/mlueckhof/PhD/Notes/IRDesign/data/FCCeeParamList.xlsx'
FCCeeParams = DataReader.readParams(file)
FCCeeParams
# Out:
#                          parameter                    Z                    W  \
# 0                beam energy [GeV]                 45.6                   80
# 1                  arc cell optics                60/60                90/90
# 2        momentum compaction [E-5]                 1.48                 0.73
# 3        horizontal emittance [nm]                 0.27                 0.28
# 4          vertical emittance [pm]                    1                    1
# 5             horizontal beta* [m]                 0.15                  0.2
# 6              vertical beta* [mm]                  0.8                    1
# 7     length interaction area [mm]                 0.42                  0.5
# 8         tunes, half-ring (x,y,s)  (0.569,0.61,0.0125)  (0.577,0.61,0.0115)
# 9   longitudinal damping time [ms]                  414                   77
# 10       SR energy loss/turn [GeV]                0.036                 0.34
# 11           total RF voltage [GV]                  0.1                 0.44
# 12               RF acceptance [%]                  1.9                  1.9
# 13           energy acceptance [%]                  1.3                  1.3
# 14       energy spread (SR/BS) [%]          0.038/0.132          0.066/0.153
# 15       bunch length (SR/BS) [mm]             3.5/12.1             3.3/7.65
# 16         Piwinski angle (SR/BS)              8.2/28.5             6.6/15.3
# 17           bunch intensity [E11]                  1.7                  1.5
# 18                    bunches/beam                16640                 2000
# 19               beam current [mA]                 1390                  147
# 20    Luminosity [10^34 cm^-2s^-1]                  230                   32
# 21       Beam-beam parameter (x/y)          0.004/0.133         0.0065/0.118
# 22       luminosity lifetime [min]                   70                   50
# 23   time between injections [sec]                  122                   44
# 24         allowable asymmetry [%]                    5                    3
# 25   required lifetime by BS [min]                   29                   16
# 26     actual lifetime by BS [min]                > 200                   20
#
#                  H (ZH)                ttbar
# 0                   120                  175
# 1                 90/90                90/90
# 2                  0.73                 0.73
# 3                  0.63                 1.34
# 4                   1.3                  2.7
# 5                   0.3                    1
# 6                     1                    2
# 7                   0.9                 1.95
# 8   (0.565,0.60,0.0180)  (0.553,0.59,0.0343)
# 9                    23                  7.5
# 10                 1.72                  7.8
# 11                    2                  9.5
# 12                  2.3                    5
# 13                  1.5                  2.5
# 14          0.099/0.151          0.147/0.192
# 15             3.15/4.9            2.45/3.25
# 16              3.4/5.3             1.0/1.33
# 17                  1.5                  2.7
# 18                  393                   48
# 19                   29                  6.4
# 20                  7.8                  1.8
# 21          0.016/0.108          0.095/0.157
# 22                   42                   39
# 23                   31                   32
# 24                    3                    3
# 25                   11                   12
# 26                   20                   24

# %% [markdown]
# Data Visualization Level
# ==============
# At this stage, the data can be plotted using the methods from class VisSRDat

# %%
Selection = DataSelection(DFseco_col)
def_opt = Selection.opticsSelection(optics = ['fcc_ee_t_85_by2_nosol','fcc_ee_t_205_nosol'], verbose = 0)
beamTypes, beamSizes = Selection.get_beamShapes_and_Size(verbose = 1)
# Out:
# *-*-*-*-*-*-*-*-*-*-*-*-*
#  Available types: {'ring', 'flat', 'gauss', 'pencil'}
#  Available sizes: {0, 1, 10, 5}

# %%
plotpath = '/home/mlueckhof/temporary/'
pltdat.plot_diffBeamShape(def_opt, plotpath, beamTypes, beamSizes, Type = 'origin', 
                          beam = ['gauss','flat'], size = [1], verbose = 0, save = 1)
# Out:
# Found no collimator frame - analysing default data
#  -----------------------------
# Type gauss selected, with size 1 sigma
# Type flat selected, with size 1 sigma
# saved plot as /home/mlueckhof/temporary/ SR_origin_beamshape.pdf

# %% [markdown]
# Photon Collimation
# ===========

# %%
# create the DF's - collimation should be grouped as several cases have to be studied.
#
originSR_col = DataReader(path='/home/mlueckhof/Codes/Projects/FCCee/Collimator/')

# originSR_col = aper_select(originSR_col, aperture = [1030,3030])
# originSR_col.name = 'originSR_col'
# % timeit 
# pltdat.plot_data(originSR_def, Type = 'origin', save = 1)
plotpath = '/home/mlueckhof/Codes/MDI/Analysis_Processing/Analysis/Plots/'
# pltdat.plot_data(originSR_col, Type = 'hit', save = 1, aperture = [3010])
pltdat.plot_data(originSR_col, Type = 'hit', save = 1, aperture = [1030])
# Out:
#  ***********************************************
#  accessing directory: /home/mlueckhof/Codes/Projects/FCCee/Default/Data/
#   ==> no sub directories.
#   ==> found data
#     --> added following files:
#   ['fcc_ee_t_85_by2_nosol_seco_ntuple.out']
#  ***********************************************
#  filling data frames
#  --> appending file /home/mlueckhof/Codes/Projects/FCCee/Default/Data/fcc_ee_t_85_by2_nosol_seco_ntuple.out ...
# done.
#  ***********************************************
#  accessing directory: /home/mlueckhof/Codes/Projects/FCCee/Collimator/Data/
#   ==> no sub directories.
#   ==> found data
#     --> added following files:
#   ['fcc_ee_t_85_by2_nosol_coll_3015_seco_ntuple.out', 'fcc_ee_t_85_by2_nosol_coll_1030_seco_ntuple.out', 'fcc_ee_t_85_by2_nosol_coll_3010_seco_ntuple.out', 'fcc_ee_t_85_by2_nosol_coll_2030_seco_ntuple.out', 'fcc_ee_t_85_by2_nosol_coll_1530_seco_ntuple.out', 'fcc_ee_t_85_by2_nosol_coll_3020_seco_ntuple.out', 'fcc_ee_t_85_by2_nosol_coll_3030_seco_ntuple.out']
#  ***********************************************
#  filling data frames
# found aperture: 3015
#  --> appending file
#  /home/mlueckhof/Codes/Projects/FCCee/Collimator/Data/fcc_ee_t_85_by2_nosol_coll_3015_seco_ntuple.out ...
# done.
# found aperture: 1030
#  --> appending file
#  /home/mlueckhof/Codes/Projects/FCCee/Collimator/Data/fcc_ee_t_85_by2_nosol_coll_1030_seco_ntuple.out ...
# done.
# found aperture: 3010
#  --> appending file
#  /home/mlueckhof/Codes/Projects/FCCee/Collimator/Data/fcc_ee_t_85_by2_nosol_coll_3010_seco_ntuple.out ...
# done.
# found aperture: 2030
#  --> appending file
#  /home/mlueckhof/Codes/Projects/FCCee/Collimator/Data/fcc_ee_t_85_by2_nosol_coll_2030_seco_ntuple.out ...
# done.
# found aperture: 1530
#  --> appending file
#  /home/mlueckhof/Codes/Projects/FCCee/Collimator/Data/fcc_ee_t_85_by2_nosol_coll_1530_seco_ntuple.out ...
# done.
# found aperture: 3020
#  --> appending file
#  /home/mlueckhof/Codes/Projects/FCCee/Collimator/Data/fcc_ee_t_85_by2_nosol_coll_3020_seco_ntuple.out ...
# done.
# found aperture: 3030
#  --> appending file
#  /home/mlueckhof/Codes/Projects/FCCee/Collimator/Data/fcc_ee_t_85_by2_nosol_coll_3030_seco_ntuple.out ...
# done.
# found collimator frame - groupby 'CollDim'
#  -----------------------------
# aperture selected: 1030
# 1030
# saved plot as /home/mlueckhof/Codes/MDI/Analysis_Processing/Analysis/Plots/ SR_hits_coll.pdf

# %% [markdown]
# SR photons per element
# ======================

# %%
ElementName = 'BWL_2_15037_v'
originSR_Elm = FCCee_secondaries[(FCCee_secondaries.Creator == 'SynRad') & (FCCee_secondaries.charge == 0) &
                                 (FCCee_secondaries.name == ElementName)] 

event_last = 999999999
track_last = 999999999
vis = 1; save = 0 
nBin = 100

Z_org = []; Z_hit = []; E_org = []; E_hit = []; Material = []
for row in originSR_Elm.index:
    event = originSR_Elm.get_value(row,'Event')
    track = originSR_Elm.get_value(row,'Track')
    z_eu  = originSR_Elm.get_value(row,'z_eu')
    mat   = originSR_Elm.get_value(row,'Material')
    energ = originSR_Elm.get_value(row,'ptot')
    if(event_last != event or track_last != track):
        event_last = event
        track_last = track
        Z_org.append(z_eu)
        E_org.append(energ*10**6)
    elif(mat == 'Cu'):
        Z_hit.append(z_eu)
        E_hit.append(energ)

if(vis == 1):
    plt.figure(1)
    plt.title("Origin of SR photons")
    plt.rc('grid', linestyle="--", color='grey')
    plt.grid()
    plt.hist(Z_org, bins = nBin, range = (-550, 0))
    plt.xlabel("z [m]")
    plt.ylabel("photons/bin")
    if(save == 1):
        plt.savefig(plotpath+'SR_origin.pdf')
    else:
        pass
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-c7c72593964b> in <module>()
#       1 ElementName = 'BWL_2_15037_v'
# ----> 2 originSR_Elm = FCCee_secondaries[(FCCee_secondaries.Creator == 'SynRad') & (FCCee_secondaries.charge == 0) &
#       3                                  (FCCee_secondaries.name == ElementName)]
#       4
#       5 event_last = 999999999
#
# NameError: name 'FCCee_secondaries' is not defined
